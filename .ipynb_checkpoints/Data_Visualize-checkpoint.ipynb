# %% [markdown]
# # I. Import các thư viện cần thiết

# %%
import numpy as np
import pandas as pd   
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # II. Đọc Data vào Dataframe. Data được thu thập thủ công từ trang https://www.worldometers.info/coronavirus/ vào ngày 02/05/2022

# %%
Data = pd.read_csv('data.csv',sep=';')

# %%
Data
# Out:
#          # Country, Other  Total Cases New Cases Total Deaths  New Deaths  \
# 0      NaN          World  513,697,783   154,755    6,262,191       623.0
# 1      1.0            USA   83,083,425       NaN    1,020,854         NaN
# 2      2.0          India   43,082,502       NaN      523,869         NaN
# 3      3.0         Brazil   30,454,490       NaN      663,567         NaN
# 4      4.0         France   28,682,011       NaN      145,962         NaN
# ..     ...            ...          ...       ...          ...         ...
# 224  224.0     MS Zaandam            9       NaN            2         NaN
# 225  225.0           Niue            9       NaN          NaN         NaN
# 226  226.0     Micronesia            7       NaN          NaN         NaN
# 227  227.0          Nauru            5       NaN          NaN         NaN
# 228  228.0   Saint Helena            2       NaN          NaN         NaN
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 0       467,939,862       337,659   39,495,730            40,904
# 1        80,719,929           NaN    1,342,642             1,554
# 2        42,538,976           NaN       19,657               698
# 3        29,533,039           NaN      257,884             8,318
# 4        26,826,905           NaN    1,709,144             1,557
# ..              ...           ...          ...               ...
# 224               7           NaN            0               NaN
# 225               7           NaN            2               NaN
# 226               1           NaN            6               NaN
# 227               3           NaN            2               NaN
# 228               2           NaN            0               NaN
#
#     Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/1M pop  \
# 0              65,903          803.4            NaN          NaN
# 1             248,345          3,051  1,005,593,629    3,005,820
# 2              30,668            373    838,208,698      596,678
# 3             141,438          3,082     63,776,166      296,193
# 4             437,643          2,227    266,484,045    4,066,138
# ..                ...            ...            ...          ...
# 224               NaN            NaN            NaN          NaN
# 225             5,468            NaN            NaN          NaN
# 226                60            NaN            NaN          NaN
# 227               457            NaN            NaN          NaN
# 228               327            NaN            NaN          NaN
#
#         Population
# 0              NaN
# 1      334,548,810
# 2    1,404,791,509
# 3      215,319,917
# 4       65,537,387
# ..             ...
# 224            NaN
# 225          1,646
# 226        117,226
# 227         10,948
# 228           6,11
#
# [229 rows x 15 columns]

# %% [markdown]
# # III. Tiền xử lí dữ liệu

# %%
def data_preprocessing(Data):
    for col_name in Data:
        temp = []     
        for col in Data[col_name]:
            col = str(col)
            col = col.replace(',','')
            try:   
                col = int(col)
            except:
                pass
            temp.append(col)
        Data[col_name] = temp
    return Data

# %%
Data = Data.fillna(0)
Data = data_preprocessing(Data) 
Data
# Out:
#          # Country, Other  Total Cases  New Cases  Total Deaths New Deaths  \
# 0      0.0          World    513697783     154755       6262191      623.0
# 1      1.0            USA     83083425          0       1020854        0.0
# 2      2.0          India     43082502          0        523869        0.0
# 3      3.0         Brazil     30454490          0        663567        0.0
# 4      4.0         France     28682011          0        145962        0.0
# ..     ...            ...          ...        ...           ...        ...
# 224  224.0     MS Zaandam            9          0             2        0.0
# 225  225.0           Niue            9          0             0        0.0
# 226  226.0     Micronesia            7          0             0        0.0
# 227  227.0          Nauru            5          0             0        0.0
# 228  228.0   Saint Helena            2          0             0        0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# 0          467939862         337659      39495730              40904
# 1           80719929              0       1342642               1554
# 2           42538976              0         19657                698
# 3           29533039              0        257884               8318
# 4           26826905              0       1709144               1557
# ..               ...            ...           ...                ...
# 224                7              0             0                  0
# 225                7              0             2                  0
# 226                1              0             6                  0
# 227                3              0             2                  0
# 228                2              0             0                  0
#
#      Tot Cases/ 1M pop Deaths/ 1M pop  Total Tests  Tests/1M pop  Population
# 0                65903          803.4            0             0           0
# 1               248345           3051   1005593629       3005820   334548810
# 2                30668            373    838208698        596678  1404791509
# 3               141438           3082     63776166        296193   215319917
# 4               437643           2227    266484045       4066138    65537387
# ..                 ...            ...          ...           ...         ...
# 224                  0              0            0             0           0
# 225               5468              0            0             0        1646
# 226                 60              0            0             0      117226
# 227                457              0            0             0       10948
# 228                327              0            0             0         611
#
# [229 rows x 15 columns]

# %% [markdown]
# # IV. Trực quan hóa với các mô hình

# %% [markdown]
# ## 1. Top 10 quốc gia có tổng số ca nhiễm cao nhất thế giới
#
# (Trường được chọn: "Country, Other" và "Total Cases")

# %%
data_non_world = Data.drop([0])
data_non_world
# Out:
#          # Country, Other  Total Cases  New Cases  Total Deaths New Deaths  \
# 1      1.0            USA     83083425          0       1020854        0.0
# 2      2.0          India     43082502          0        523869        0.0
# 3      3.0         Brazil     30454490          0        663567        0.0
# 4      4.0         France     28682011          0        145962        0.0
# 5      5.0        Germany     24791190      20595        135947       34.0
# ..     ...            ...          ...        ...           ...        ...
# 224  224.0     MS Zaandam            9          0             2        0.0
# 225  225.0           Niue            9          0             0        0.0
# 226  226.0     Micronesia            7          0             0        0.0
# 227  227.0          Nauru            5          0             0        0.0
# 228  228.0   Saint Helena            2          0             0        0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# 1           80719929              0       1342642               1554
# 2           42538976              0         19657                698
# 3           29533039              0        257884               8318
# 4           26826905              0       1709144               1557
# 5           22469200           1132       2186043               1446
# ..               ...            ...           ...                ...
# 224                7              0             0                  0
# 225                7              0             2                  0
# 226                1              0             6                  0
# 227                3              0             2                  0
# 228                2              0             0                  0
#
#      Tot Cases/ 1M pop Deaths/ 1M pop  Total Tests  Tests/1M pop  Population
# 1               248345           3051   1005593629       3005820   334548810
# 2                30668            373    838208698        596678  1404791509
# 3               141438           3082     63776166        296193   215319917
# 4               437643           2227    266484045       4066138    65537387
# 5               294176           1613    122332384       1451613    84273389
# ..                 ...            ...          ...           ...         ...
# 224                  0              0            0             0           0
# 225               5468              0            0             0        1646
# 226                 60              0            0             0      117226
# 227                457              0            0             0       10948
# 228                327              0            0             0         611
#
# [228 rows x 15 columns]

# %%
data_non_world = Data.drop([0])
df_groupbyCase=data_non_world.groupby("Country, Other",axis=0).sum()
df_groupbyCase.sort_values(by="Total Cases",ascending=False,axis=0,inplace=True)
df_groupbyCase=df_groupbyCase.head(10)
df_groupbyCase=df_groupbyCase["Total Cases"]
df_groupbyCase
# Out:
# Country, Other
# USA         83083425
# India       43082502
# Brazil      30454490
# France      28682011
# Germany     24791190
# UK          22038340
# Russia      18195608
# S. Korea    17295733
# Italy       16504791
# Turkey      15033573
# Name: Total Cases, dtype: int64

# %%
explode_list=[0,0,0,0,0,0,0.25,0.2,0.2,0.1]
df_groupbyCase.plot(kind='pie',figsize=(15,6),autopct="%1.1f%%",startangle=90,labels=None,pctdistance=1.1
                            ,explode=explode_list,colors = sns.color_palette('bright')[0:10])
plt.title("Top 10 countries with the most Total cases")
plt.axis('equal')
plt.legend(labels=df_groupbyCase.index,loc='upper left');

# %% [markdown]
# ## 2. Biểu đồ thể hiện tương quan trong các ca nhiễm
#
# (Trường được chọn: "Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "Active Cases", "Serious, Critical")

# %%
features = ["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","Active Cases","Serious, Critical"]
case_corr = Data[features].corr()
case_corr
# Out:
#                    Total Cases  New Cases  Total Deaths  Total Recovered  \
# Total Cases           1.000000   0.935821      0.995217         0.999242
# New Cases             0.935821   1.000000      0.922402         0.929686
# Total Deaths          0.995217   0.922402      1.000000         0.995338
# Total Recovered       0.999242   0.929686      0.995338         1.000000
# Active Cases          0.984333   0.950530      0.978113         0.982326
# Serious, Critical     0.969603   0.919567      0.978374         0.968264
#
#                    Active Cases  Serious, Critical
# Total Cases            0.984333           0.969603
# New Cases              0.950530           0.919567
# Total Deaths           0.978113           0.978374
# Total Recovered        0.982326           0.968264
# Active Cases           1.000000           0.970091
# Serious, Critical      0.970091           1.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(case_corr,cmap="YlGnBu",vmin=0, annot=True, square=True);

# %% [markdown]
# Nhiều trường có mối quan hệ nhân quả (cause-effect) với nhau, ví dụ như tỉ lệ giữa số ca nhiễm - số ca chết, số ca nhiễm - số ca hồi phục và số ca nghiêm trọng - số ca chết)

# %%
sns.regplot(x="Total Cases",y="Total Deaths",data=Data);

# %%
sns.regplot(x="Total Cases",y="Total Recovered",data=Data);

# %% [markdown]
# Ta thấy tỉ lệ giữa số ca mắc so với số ca tử vong/hồi phục rất đều nhau, nghĩa là càng có nhiều người nhiễm bệnh thì số người chết và số người hết bệnh cũng tăng với tỉ lệ gần như tương tự.

# %%
sns.regplot(x="Total Deaths",y="Serious, Critical",data=Data);

# %% [markdown]
# Trái ngược với nhận ở trên, tỉ lệ giữa số ca nghiêm trọng/số ca tử vong ngày càng cách xa nhau, tức là nhiều ca nghiêm trọng cũng không hẳn là số ca tử vong cũng tăng tới tỉ lệ tương tự.
